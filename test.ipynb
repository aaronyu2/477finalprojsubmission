# %%
import pandas as pd
df = pd.read_feather("data/hupd_all_train.feather")

# %%
df_metadata = pd.read_feather("data/hupd_metadata_2022-02-22.feather")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373511 entries, 0 to 373510
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   patent_number      373511 non-null  object
#  1   decision           373511 non-null  object
#  2   title              373511 non-null  object
#  3   abstract           373511 non-null  object
#  4   claims             373511 non-null  object
#  5   background         373511 non-null  object
#  6   summary            373511 non-null  object
#  7   description        373511 non-null  object
#  8   cpc_label          373511 non-null  object
#  9   ipc_label          373511 non-null  object
#  10  filing_date        373511 non-null  datetime64[ns]
#  11  patent_issue_date  373511 non-null  object
#  12  date_published     373511 non-null  object
#  13  examiner_id        373511 non-null  object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 39.9+ MB

# %%
df_metadata["filing_title"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/cs477-final-project/.conda/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'filing_title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_metadata["filing_title"]
#
# ...

# %%
df_join = pd.merge(df, df_metadata, left_on=["title", "filing_date"], right_on=["invention_title", "filing_date"], how="inner")

# %%
df_join.to_feather("data/hupd_all_train_merged.feather")

# %%
df_join["publication_number"]
# Out:
# 0         US20160113069A1-20160421
# 1         US20160106107A1-20160421
# 2         US20160128679A1-20160512
# 3         US20100291042A1-20101118
# 4         US20150116720A1-20150430
#                     ...
# 378731    US20180077964A1-20180322
# 378732    US20170238622A1-20170824
# 378733    US20180026122A1-20180125
# 378734    US20180071370A1-20180315
# 378735    US20180263475A1-20180920
# Name: publication_number, Length: 378736, dtype: object

# %%
df_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378736 entries, 0 to 378735
# Data columns (total 46 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   patent_number_x             378736 non-null  object
#  1   decision_x                  378736 non-null  object
#  2   title                       378736 non-null  object
#  3   abstract                    378736 non-null  object
#  4   claims                      378736 non-null  object
#  5   background                  378736 non-null  object
#  6   summary                     378736 non-null  object
#  7   description                 378736 non-null  object
#  8   cpc_label                   378736 non-null  object
#  9   ipc_label                   378736 non-null  object
#  10  filing_date                 378736 non-null  datetime64[ns]
#  11  patent_issue_date_x         378736 non-null  object
# ...

# %%
df["title"].head()
# Out:
# 0                                  Induction Coil Unit
# 1    Compositions and Methods for Treating Microorg...
# 2                                HAEMOSTAT APPLICATION
# 3              MULTIPOTENT STEM CELLS AND USES THEREOF
# 4    COMPACT SPECTROMETER FOR TWO-DIMENSIONAL SAMPLING
# Name: title, dtype: object

# %%
df_metadata["invention_title"]
# Out:
# 0          Stable expression of polymorphous forms of hum...
# 1                               Connecting device for fluids
# 2          PROCESS FOR PREPARING OPTICALLY ACTIVE 2-[6-(H...
# 3                METHOD FOR WORKING AND PROCESSING MATERIALS
# 4          SYSTEM AND METHOD FOR CREATING A SEARCHABLE WO...
#                                  ...
# 4518249                                PYROTECHNICAL IGNITER
# 4518250                      CAPSULE CUP OF A COFFEE CAPSULE
# 4518251    AIRBAG DEVICE FOR A MOTOR VEHICLE, AND AIRBAG ...
# 4518252    LIPID FORMULATIONS CONTAINING BIOACTIVE FATTY ...
# 4518253                  THREE-DIMENSIONAL PROCESSING DEVICE
# Name: invention_title, Length: 4518254, dtype: object

# %%
df_metadata.head()
# Out:
#   application_number filing_date application_invention_type  \
# 0           10018320  2004-06-29                    Utility
# 1           10018639  2004-03-15                    Utility
# 2           10048553  2004-10-18                    Utility
# 3           10048576  2005-03-28                    Utility
# 4           10049016  2004-06-08                    Utility
#
#          examiner_full_name examiner_art_unit uspc_class uspc_subclass  \
# 0  MITCHELL, LAURA MCGILLEM              1636        435        007400
# 1               FOX, JOHN C              3753        137        884000
# 2         SAUCIER, SANDRA E              1651        435        280000
# 3             FRANCIS, FAYE              3725        241        001000
# 4               LE, MICHAEL              2163        707        100000
#
#    confirm_number atty_docket_number  \
# 0          1633.0            01-1637
# 1          5181.0     442-134 PCT/US
# 2          4574.0         21581/0286
# ...

# %%
df2 = pd.read_feather("data/hupd_sample_train_merged.feather")

# %%
df.head()
# Out:
#   patent_number_x decision_x  \
# 0        11883905    PENDING
# 1        11913160   REJECTED
# 2        12524548    PENDING
# 3        12598047   REJECTED
# 4        12935772   ACCEPTED
#
#                                                title  \
# 0                                Induction Coil Unit
# 1  Compositions and Methods for Treating Microorg...
# 2                              HAEMOSTAT APPLICATION
# 3            MULTIPOTENT STEM CELLS AND USES THEREOF
# 4  COMPACT SPECTROMETER FOR TWO-DIMENSIONAL SAMPLING
#
#                                             abstract  \
# 0  According to the invention, for shrinking and ...
# 1  The invention is a method and composition for ...
# 2  A tool for application of a haemostat to a sit...
# 3  The invention provides a quiescent stem cell h...
# 4  The present invention relates to a spectromete...
#
#                                               claims  \
# 0  1. An induction coil unit for heating a compon...
# ...

# %%
df2["publication_number"].head()
# Out:
# 0    US20170326033A1-20171116
# 1    US20160130721A1-20160512
# 2    US20160128423A1-20160512
# 3    US20170087696A1-20170330
# 4    US20160185938A1-20160630
# Name: publication_number, dtype: object

# %%
df.head()
# Out:
#   patent_number_x decision_x  \
# 0        11883905    PENDING
# 1        11913160   REJECTED
# 2        12524548    PENDING
# 3        12598047   REJECTED
# 4        12935772   ACCEPTED
#
#                                                title  \
# 0                                Induction Coil Unit
# 1  Compositions and Methods for Treating Microorg...
# 2                              HAEMOSTAT APPLICATION
# 3            MULTIPOTENT STEM CELLS AND USES THEREOF
# 4  COMPACT SPECTROMETER FOR TWO-DIMENSIONAL SAMPLING
#
#                                             abstract  \
# 0  According to the invention, for shrinking and ...
# 1  The invention is a method and composition for ...
# 2  A tool for application of a haemostat to a sit...
# 3  The invention provides a quiescent stem cell h...
# 4  The present invention relates to a spectromete...
#
#                                               claims  \
# 0  1. An induction coil unit for heating a compon...
# ...
